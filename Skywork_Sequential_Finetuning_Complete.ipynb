# %% [markdown]
# <a href="https://colab.research.google.com/github/poppingtonic/neural_networks_solomonoff_induction/blob/feat%2FRM-finetune/Skywork_Sequential_Finetuning_Complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 Skywork Sequential Fine-tuning - Complete Guide
#
# **All-in-one notebook** for training with UTM → CTW curriculum.
#
# ## Features
# - ✅ SWAG-LoRA: 99% parameter reduction
# - ✅ Multiple architectures: LSTM, Skywork
# - ✅ Memory optimized for Colab (15GB)
# - ✅ Uncertainty quantification
#
# **Setup**: Runtime → Change runtime type → GPU

# %%
# 1. Check GPU
# !nvidia-smi --query-gpu=name,memory.total --format=csv
# Out:
# name, memory.total [MiB]
# NVIDIA A100-SXM4-40GB, 40960 MiB

# %%
# 2. Install dependencies
# !pip install -q torch transformers peft bitsandbytes accelerate numpy
# !pip install -q git+https://github.com/fortuinlab/swag-lora.git
# !pip install -q "jax[cuda12]" jaxlib dm-haiku optax chex jaxtyping
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 5.9 MB/s eta 0:00:00

# %%
# 3. Clone repo
# !git clone https://github.com/poppingtonic/neural_networks_solomonoff_induction.git
# %cd neural_networks_solomonoff_induction
# !git checkout feat/RM-finetune
# Out:
# Cloning into 'neural_networks_solomonoff_induction'...
# remote: Enumerating objects: 259, done.
# remote: Counting objects: 100% (187/187), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 259 (delta 68), reused 155 (delta 51), pack-reused 72 (from 1)
# Receiving objects: 100% (259/259), 441.51 KiB | 29.43 MiB/s, done.
# Resolving deltas: 100% (99/99), done.
# /content/neural_networks_solomonoff_induction/neural_networks_solomonoff_induction
# Branch 'feat/RM-finetune' set up to track remote branch 'feat/RM-finetune' from 'origin'.
# Switched to a new branch 'feat/RM-finetune'

# %% [markdown]
# ## Configuration
#
# **OPTION 1**: LSTM (~2GB, fastest)
# **OPTION 2**: Skywork + LoRA (~4GB, recommended ⭐)
# **OPTION 3**: Skywork + SWAG-LoRA (~4.5GB, best quality)
# **OPTION 4**: Skywork Full (~12GB, Colab Pro)
# **OPTION 5**: Quick Test (5 min)

# %%
# Select configuration (change number 1-5)
SELECTED = 4

import torch
import gc

if torch.cuda.is_available():
    torch.cuda.empty_cache()
    gc.collect()
    mem = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f'GPU: {torch.cuda.get_device_name(0)} ({mem:.1f}GB)')
else:
    print('⚠️ No GPU! Enable in Runtime settings')
# Out:
# GPU: NVIDIA A100-SXM4-40GB (42.5GB)

# %% [markdown]
# ## Training Commands
#
# Run ONE of the cells below based on your selection.

# %%
# OPTION 1: LSTM (Most Efficient)
# !python torch_training/train_sequential_finetune.py \
  --architecture lstm \
  --hidden_dim 256 \
  --num_layers 2 \
  --stage all \
  --utm_steps 5000 \
  --ctw_steps 2500 \
  --batch_size 16 \
  --seq_length 256 \
  --device cuda

# %%
# OPTION 2: Skywork + LoRA (Recommended ⭐)
# !python torch_training/train_sequential_finetune.py \
  --model_name_or_path 'Skywork/Skywork-Reward-V2-Qwen3-0.6B' \
  --use_hf \
  --stage all \
  --utm_steps 5000 \
  --ctw_steps 2500 \
  --batch_size 16 \
  --seq_length 256 \
  --device cuda

# %%
# OPTION 3: Skywork + SWAG-LoRA (Best Quality)
# !python torch_training/train_sequential_finetune.py \
  --model_name_or_path 'Skywork/Skywork-Reward-V2-Qwen3-0.6B' \
  --use_hf \
  --use_lora \
  --lora_r 8 \
  --use_swag \
  --swag_start_epoch 10 \
  --stage all \
  --utm_steps 5000 \
  --ctw_steps 2500 \
  --batch_size 16 \
  --seq_length 256 \
  --device cuda

# %%
# !ln -s /content/neural_networks_solomonoff_induction/neural_networks_solomonoff_induction/data /content/neural_networks_solomonoff_induction/neural_networks_solomonoff_induction/torch_training/data

# %%
# !ls -lash torch_training
# Out:
# total 128K
# 4.0K drwxr-xr-x  2 root root 4.0K Oct 28 00:08 .
# 4.0K drwxr-xr-x 12 root root 4.0K Oct 28 00:05 ..
# 4.0K lrwxrwxrwx  1 root root   87 Oct 28 00:08 data -> /content/neural_networks_solomonoff_induction/neural_networks_solomonoff_induction/data
# 8.0K -rw-r--r--  1 root root 7.6K Oct 28 00:05 dni_adapter.py
#  16K -rw-r--r--  1 root root  15K Oct 28 00:05 dni.py
#  12K -rw-r--r--  1 root root 9.4K Oct 28 00:05 evaluate_sequential.py
# 4.0K -rw-r--r--  1 root root  533 Oct 28 00:05 __init__.py
# 4.0K lrwxrwxrwx  1 root root   64 Oct 28 00:05 models -> /data/backup-src/src/neural_networks_solomonoff_induction/models
# 4.0K -rw-r--r--  1 root root 3.8K Oct 28 00:05 mswag_demo_toy.py
# 4.0K -rw-r--r--  1 root root 2.6K Oct 28 00:05 mswag_integration.py
# 4.0K -rw-r--r--  1 root root 2.3K Oct 28 00:05 mswag_utils.py
#  12K -rw-r--r--  1 root root 9.4K Oct 28 00:05 swag_lora_adapter.py
# 4.0K lrwxrwxrwx  1 root root   70 Oct 28 00:05 torch_models -> /data/backup-src/src/neural_networks_solomonoff_induction/torch_models
#  24K -rw-r--r--  1 root root  21K Oct 28 00:05 train_sequential_finetune.py
# 8.0K -rw-r--r--  1 root root 7.3K Oct 28 00:05 train_sml.py
# 8.0K -rw-r--r--  1 root root 7.9K Oct 28 00:05 train_torch.py
# 4.0K -rw-r--r--  1 root root  944 Oct 28 00:05 utm_dataset.py

# %%
# !ln -s /content/neural_networks_solomonoff_induction/neural_networks_solomonoff_induction/models /content/neural_networks_solomonoff_induction/neural_networks_solomonoff_induction/torch_training/models
# !ln -s /content/neural_networks_solomonoff_induction/neural_networks_solomonoff_induction/torch_models /content/neural_networks_solomonoff_induction/neural_networks_solomonoff_induction/torch_training/torch_models

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# OPTION 4: Skywork Full (Colab Pro)
# !python torch_training/train_sequential_finetune.py \
  --model_name_or_path 'Skywork/Skywork-Reward-V2-Qwen3-0.6B' \
  --use_hf \
  --stage all \
  --utm_steps 3000 \
  --ctw_steps 1500 \
  --batch_size 4 \
  --seq_length 128 \
  --device cuda
  --output_dir /content/drive/MyDrive/skywork_checkpoints
# Out:
# [DNI] Warning: DNI module not available. Install or check path.
# Loading HuggingFace model: Skywork/Skywork-Reward-V2-Qwen3-0.6B
# config.json: 100% 846/846 [00:00<00:00, 4.89MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2025-10-28 00:11:31.153015: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761610291.174557    8320 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761610291.181041    8320 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761610291.197517    8320 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761610291.197543    8320 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761610291.197546    8320 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761610291.197549    8320 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# model.safetensors: 100% 1.19G/1.19G [00:11<00:00, 106MB/s]
# tokenizer_config.json: 5.41kB [00:00, 10.9MB/s]
# vocab.json: 2.78MB [00:00, 126MB/s]
# merges.txt: 1.67MB [00:00, 8.00MB/s]
# tokenizer.json: 100% 11.4M/11.4M [00:02<00:00, 3.91MB/s]
# added_tokens.json: 100% 707/707 [00:00<00:00, 4.81MB/s]
# special_tokens_map.json: 100% 500/500 [00:00<00:00, 4.80MB/s]
# chat_template.jinja: 4.17kB [00:00, 16.2MB/s]
# ✓ Loaded model with vocab_size=151669
# Sequential Finetuning Pipeline
# Model: Skywork/Skywork-Reward-V2-Qwen3-0.6B
# Architecture: lstm
# Device: cuda
# Output: ./checkpoints/sequential
# Note: LSTMs generalize better to longer sequences (https://arxiv.org/html/2401.14953v1)
#
# ============================================================
# STAGE 1: UTM Finetuning (3000 steps)
# ============================================================
# Traceback (most recent call last):
#   File "/content/neural_networks_solomonoff_induction/neural_networks_solomonoff_induction/torch_training/train_sequential_finetune.py", line 610, in <module>
#     main()
#   File "/content/neural_networks_solomonoff_induction/neural_networks_solomonoff_induction/torch_training/train_sequential_finetune.py", line 576, in main
#     finetuner.train_stage_utm(
#   File "/content/neural_networks_solomonoff_induction/neural_networks_solomonoff_induction/torch_training/train_sequential_finetune.py", line 190, in train_stage_utm
#     metrics = self.train_step_utm(data_generator, optimizer)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/neural_networks_solomonoff_induction/neural_networks_solomonoff_induction/torch_training/train_sequential_finetune.py", line 99, in train_step_utm
#     log_probs = self.model(x)
#                 ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py", line 918, in wrapper
#     output = func(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py", line 480, in forward
#     outputs: BaseModelOutputWithPast = self.model(
#                                        ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py", line 1064, in wrapper
#     outputs = func(self, *args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py", line 410, in forward
#     hidden_states = decoder_layer(
#                     ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py", line 94, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/deprecation.py", line 172, in wrapped_func
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py", line 260, in forward
#     hidden_states, _ = self.self_attn(
#                        ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/deprecation.py", line 172, in wrapped_func
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py", line 205, in forward
#     query_states, key_states = apply_rotary_pos_emb(query_states, key_states, cos, sin)
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py", line 115, in apply_rotary_pos_emb
#     q_embed = (q * cos) + (rotate_half(q) * sin)
#                            ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py", line 90, in rotate_half
#     return torch.cat((-x2, x1), dim=-1)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# OPTION 5: Quick Test (5 minutes)
# !python torch_training/train_sequential_finetune.py \
  --model_name_or_path 'Skywork/Skywork-Reward-V2-Qwen3-0.6B' \
  --use_hf \
  --use_lora \
  --lora_r 8 \
  --stage utm \
  --utm_steps 100 \
  --batch_size 8 \
  --seq_length 128 \
  --device cuda

# %% [markdown]
# ## Monitor Training

# %%
# Check memory
if torch.cuda.is_available():
    print(f'Allocated: {torch.cuda.memory_allocated()/1e9:.2f} GB')
    print(f'Peak: {torch.cuda.max_memory_allocated()/1e9:.2f} GB')

# %%
# View logs
# !tail -30 ./checkpoints/sequential/train.log

# %% [markdown]
# ## Download Results

# %%
# Zip and download
# !zip -r checkpoints.zip ./checkpoints
from google.colab import files
files.download('checkpoints.zip')

# %% [markdown]
# ## Save to Google Drive

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')

# Copy checkpoints
# !cp -r ./checkpoints /content/drive/MyDrive/skywork_checkpoints

# %% [markdown]
# ## Troubleshooting
#
# **Out of Memory**: Reduce batch_size to 1, seq_length to 64
# **No GPU**: Runtime → Change runtime type → GPU
# **Slow**: Use OPTION 1 (LSTM) or OPTION 5 (Quick Test)
#
# ## Documentation
#
# See repository files:
# - `SWAG_LORA_GUIDE.md` - Complete LoRA guide
# - `COLAB_README.md` - Colab tips
# - `SKYWORK_FINETUNING_GUIDE.md` - Skywork details
